# %% [markdown]
# # Google Geocode APIs
# https://developers.google.com/maps/documentation/geocoding/intro

# %%
import requests
import json
from configure import gkey

# Target city
target_city = "Boise, Idaho"

# Build the endpoint URL
target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(target_city, gkey)
#Must enable the api on Google Developer Console first

# %%
# Run a request to endpoint and convert result to json
geo_data = requests.get(target_url).json()

# Print the json
print(json.dumps(geo_data, indent=4, sort_keys=True))
# Out:
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Boise",
#                     "short_name": "Boise",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Ada County",
#                     "short_name": "Ada County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Idaho",
#                     "short_name": "ID",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Boise, ID, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 43.6898951,
#                         "lng": -116.1019091
#                     },
#                     "southwest": {
#                         "lat": 43.511717,
#                         "lng": -116.3658869
#                     }
#                 },
#                 "location": {
#                     "lat": 43.6150186,
#                     "lng": -116.2023137
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.6898951,
#                         "lng": -116.1019091
#                     },
#                     "southwest": {
#                         "lat": 43.511717,
#                         "lng": -116.3658869
#                     }
#                 }
#             },
#             "place_id": "ChIJnbRH6XLxrlQRm51nNpuYW5o",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }

# %%
# Extract latitude and longitude
lat = geo_data["results"][0]["geometry"]["location"]["lat"]
lng = geo_data["results"][0]["geometry"]["location"]["lng"]

# Print the latitude and longitude
print('''
    City: {0}
    Latitude: {1}
    Longitude: {2}
    '''.format(target_city, lat, lng))
# Out:
#     City: Boise, Idaho
#     Latitude: 43.6150186
#     Longitude: -116.2023137

# %% [markdown]
# # Google Places APIs
# https://developers.google.com/maps/documentation/javascript/places#place_search_requests

# %%
# geocoordinates
target_coordinates = "43.6187102, -116.2146068"
target_search = "Chinese"
target_radius = 8000
target_type = "restaurant"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
#print(response.url)
#https://maps.googleapis.com/maps/api/place/nearbysearch/json?
#location=43.6187102%2C+-116.2146068
#&keyword=Chinese&radius=8000
#&type=restaurant
#&key=gkey

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CrQCKgEAAFfyjomL4KuTBwf8h8LJOt0UHPy7Nv7ectP94nHBsoBLmxCyhuH4DF0yOn6i0vq5VddvLYHWoNMXYgiBkCEL8WI_T6-cxIZkLKNyhMZuRvnXNmX9vJ5-FYijZTafQx-9N-G66OzoozEZzFSlpnNL1Ux13Lit8k85wGcMFo5FtH5dHKqRuJPWocxMmyfJPC9irC15a7gA7y-Kj7gKjG6Xw4PY7LGTPcjKsX6wRznItW0qUHiiUPLoqqordz9jO2naVTwdSspgu50Ptkkvrfc1TpywLan_EGSCQv8hXDev8JSPjaEI17JLhIVisw6c-64DvoGPLsJ--8xOW3uQOqB7r9E9fTTZE-zmmAGcbRkvcKGGsflaP5SvULU2GSY8nRgWR9RKgTQxXuWwKQ_Vos9B8BoSEI9EDRpxW59qhRndtfgo-vQaFELtq5OoAu1iAiC9T6UUHYuZyOOw",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6180841,
#                     "lng": -116.2031626
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61938607989273,
#                         "lng": -116.2017191701073
#                     },
#                     "southwest": {
#                         "lat": 43.61668642010729,
#                         "lng": -116.2044188298928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "e525d78c947c5527fadf72ee54777d3a3517c3a1",
#             "name": "Yen Ching Restaurant",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2268,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100923580430432684257/photos\">Steve the great</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAPs6PKlJfFsy7yCrhdRnt5Xtaa_KHJWhfdly1u7sUDKAIRumJXNCESO311q92rnE_YbZs-pBa4BtoUoRY48OZJXlc5WfTC4BeM-1PnIeL3P7BxpMsyyHqAmOEpWQfbFCgEhDYvNe_OWVCqD0OUhdPmENcGhR41Ij5mC5NiTDCM5fmo1RC3RtwCw",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJD1s29-P4rlQR0QVGxC9AWY0",
#             "plus_code": {
#                 "compound_code": "JQ9W+6P Boise, Idaho",
#                 "global_code": "85M5JQ9W+6P"
#             },
#             "price_level": 2,
#             "rating": 4.2,
#             "reference": "ChIJD1s29-P4rlQR0QVGxC9AWY0",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 277,
#             "vicinity": "305 N 9th St, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6189873,
#                     "lng": -116.2912796
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.62033712989272,
#                         "lng": -116.2900414701073
#                     },
#                     "southwest": {
#                         "lat": 43.61763747010728,
#                         "lng": -116.2927411298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "61f5604ae4b98f4178f367df4a80b246abebe85f",
#             "name": "Confucius Restaurant",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114834946914295989143/photos\">Michael Hirst</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAsSagSS1dfWOvZIdjethVYsdATDJj-jQxsHIN-ogG2I4oSHiQp6UYRnJHY6I8wA4dyuuwHOtRq-nWEFSGRvrtbmI2qyVHLaRXz8Neck_jUEBmmtjVA8BJ9yo7Qz6TPoUvEhAqGWQ8OAbIyxYalEkMTDkMGhQFiW9VZOroBT-SEQHKFsSwQpDcKQ",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJxXnvGXVWrlQRdHTY4TuLvMo",
#             "plus_code": {
#                 "compound_code": "JP95+HF Boise, Idaho",
#                 "global_code": "85M5JP95+HF"
#             },
#             "price_level": 2,
#             "rating": 4.1,
#             "reference": "ChIJxXnvGXVWrlQRdHTY4TuLvMo",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 316,
#             "vicinity": "8775 W Fairview Ave, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6251218,
#                     "lng": -116.2123933
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.62631952989272,
#                         "lng": -116.2111869701072
#                     },
#                     "southwest": {
#                         "lat": 43.62361987010728,
#                         "lng": -116.2138866298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "b1910608eed20a9557d6d9fb29675484932ad9ce",
#             "name": "North End Chinese Restaurant",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103039634556116345378/photos\">Duane Hughes</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAFQYYxpQME0RU6xTdk3lZ9dYMQv0JsDes_tmDwjmbQ72UVZqf2E2epyD5WMXxp3aTWPD_sLZ02chGKIUfqhi9ipqCmoqXIaJKo3nkRL4njQgWNBXbKy8YHYPy_MqGYjBlEhBsO6LOLcHqbz2j_cNqhBD5GhRIY8uu7p8yPq8uzPqudZ8ftI96Dg",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJP5lMQNz4rlQRPRigHmorMWw",
#             "plus_code": {
#                 "compound_code": "JQGQ+22 Boise, Idaho",
#                 "global_code": "85M5JQGQ+22"
#             },
#             "rating": 4,
#             "reference": "ChIJP5lMQNz4rlQRPRigHmorMWw",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 121,
#             "vicinity": "3955, 1806 W State St, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.5888893,
#                     "lng": -116.2776039
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59031987989272,
#                         "lng": -116.2762912701072
#                     },
#                     "southwest": {
#                         "lat": 43.58762022010728,
#                         "lng": -116.2789909298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "286cea6abbf1b8ca63e5b1d4223cf74c9998e69e",
#             "name": "Guang Zhou Restaurant",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 5312,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116824059171832136548/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAApD3b0rOoTNabGKd8FJAgC4U8maYnhjL4SJ5RJir297VxXH68oUFLZ7-9bcDvxcoamObacNzk9qz_uwk6eWXEd32FLdu2S2w2MeOPey5qmlBDKytuWin9kxwVZjRBIBkKEhA1CvDQ5Q1enktkYYTk5ylAGhT1o1gMLMv8QMJgdc6RkZyX0Pygjg",
#                     "width": 2988
#                 }
#             ],
#             "place_id": "ChIJDT-7DlJWrlQRO7rtBTzZf6s",
#             "plus_code": {
#                 "compound_code": "HPQC+HX Boise, Idaho",
#                 "global_code": "85M5HPQC+HX"
#             },
#             "price_level": 1,
#             "rating": 4.1,
#             "reference": "ChIJDT-7DlJWrlQRO7rtBTzZf6s",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 256,
#             "vicinity": "7609 W Overland Rd, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6148417,
#                     "lng": -116.2427971
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61619172989273,
#                         "lng": -116.2415368701073
#                     },
#                     "southwest": {
#                         "lat": 43.61349207010728,
#                         "lng": -116.2442365298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "1cf6836746006f010fa362260831d258ddc3d8b7",
#             "name": "Golden Star Restaurant",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1920,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113168016592032142748/photos\">John Maulin</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAf2oINM4Ws646g_nWr9KQ-X89Jb4oVNblesj72HZoLWO-3Sx4CUqL28I1TtnRXzRpsOvmiCcGEmMZGaCkmeJ6KY1aZNvdcHpzkhBTL_K-_LTpFsYP67In0ZECsZCwNlGbEhC3QW660mmh0KTxXUqT-OaxGhS0b2eLmsXwoTFup_NuTPINlkp_fg",
#                     "width": 1080
#                 }
#             ],
#             "place_id": "ChIJTctsXaL4rlQRbC1U996y4-0",
#             "plus_code": {
#                 "compound_code": "JQ74+WV Boise, Idaho",
#                 "global_code": "85M5JQ74+WV"
#             },
#             "price_level": 2,
#             "rating": 4.3,
#             "reference": "ChIJTctsXaL4rlQRbC1U996y4-0",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 388,
#             "vicinity": "1142 N Orchard St, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.612365,
#                     "lng": -116.2430364
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61361307989272,
#                         "lng": -116.2416778201073
#                     },
#                     "southwest": {
#                         "lat": 43.61091342010728,
#                         "lng": -116.2443774798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "4d5492174ac6d8559bec3d50ea75de99809e2400",
#             "name": "Wok-Inn Noodle",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117660745759032282483/photos\">Sandra Capri</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAarkyuC7bolRC5rs3Y9iC8CRv4FnRUhONNV4t8hqWdX0rBz06yxLC0rN3YGuUPuSSF5O5EBRSRbJzm-2UcUVxLcDsx4BRmc1b9n2sgrJGsAOAL-fanm_H6R6IVUfE3lfjEhCY9PKceOQO5WIarP0hKrOxGhTmWYlq8GVEMAd3c_gCEPLzLyWZsg",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJe9STjx9WrlQRnMGkKZFN9V4",
#             "plus_code": {
#                 "compound_code": "JQ64+WQ Boise, Idaho",
#                 "global_code": "85M5JQ64+WQ"
#             },
#             "price_level": 1,
#             "rating": 4.4,
#             "reference": "ChIJe9STjx9WrlQRnMGkKZFN9V4",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_takeaway",
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 167,
#             "vicinity": "4912 Emerald St, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.5908727,
#                     "lng": -116.2901825
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59222267989272,
#                         "lng": -116.2888915701073
#                     },
#                     "southwest": {
#                         "lat": 43.58952302010728,
#                         "lng": -116.2915912298928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "fd94ac3594bbff6c11b913eacb10273d996e48b0",
#             "name": "Lucky Palace Chinese Restaurant",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2952,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107131937753504663981/photos\">Carter Wigley</a>"
#                     ],
#                     "photo_reference": "CmRaAAAApgUaO730VVcQUYoPuIYB4u9b9xNKNRiyDuq79y_xG4H2UXT5rRjUxFCE45JqRFMWmbNnM_nvc2bTBU8FNxGIGQo0r1aswigVYfCqJYXBhB6XF5wLzSKjn5yGJ2PLCtweEhATIn5VmJuo2osT__IHFHJAGhSgs31AiB0baQz4gZ-Xis7XuT_LmA",
#                     "width": 5248
#                 }
#             ],
#             "place_id": "ChIJ5RKyTVZWrlQRY-t-LLVVQ9M",
#             "plus_code": {
#                 "compound_code": "HPR5+8W Boise, Idaho",
#                 "global_code": "85M5HPR5+8W"
#             },
#             "price_level": 2,
#             "rating": 3.7,
#             "reference": "ChIJ5RKyTVZWrlQRY-t-LLVVQ9M",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 110,
#             "vicinity": "8630 W Overland Rd, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6283042,
#                     "lng": -116.2467568
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.62956617989272,
#                         "lng": -116.2455265701073
#                     },
#                     "southwest": {
#                         "lat": 43.62686652010727,
#                         "lng": -116.2482262298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "0b0f80cee20a9828830a5d2afc4b35e9cae20d53",
#             "name": "Golden Wok",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3492,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117660745759032282483/photos\">Sandra Capri</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA6CMryJvQ6OUS75lEb378UeDC6DBR4SGelUpZb0k9i5ICdtVYgTDTTgExCBQqnLrsMDMmMYAPX8x3LraqBFG5SL8O13DQi4M6MmYAhBIVzww6szlCeBRVSduaEnRSPVJwEhCHGkiLNyILSOuBLsJ8zE40GhRmaurGNyOVp5xrRd_-hyfvbWhTfA",
#                     "width": 4656
#                 }
#             ],
#             "place_id": "ChIJ4-wGxrP4rlQRQBpLRX5r_t0",
#             "plus_code": {
#                 "compound_code": "JQH3+87 Garden City, Idaho",
#                 "global_code": "85M5JQH3+87"
#             },
#             "price_level": 2,
#             "rating": 3.9,
#             "reference": "ChIJ4-wGxrP4rlQRQBpLRX5r_t0",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 240,
#             "vicinity": "6412, 3948 W Chinden Blvd, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6487196,
#                     "lng": -116.246199
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.65013982989272,
#                         "lng": -116.2449386701073
#                     },
#                     "southwest": {
#                         "lat": 43.64744017010728,
#                         "lng": -116.2476383298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "1d24153141ea5604e7f247978036ec0b8f45d75b",
#             "name": "New Garden Chinese Restaurant",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1920,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107509501816582528738/photos\">Emily Siess Donnellan</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAq3RpdN4iDgZtnjVA2PbTvkx-zLub5PxvVGH_CbM2D0qlrOKbhS7vfS9x5Dxr3yDQeXpu4VNqMd9UxN4GQJVvORXYa4lB6mAKejLFWpz606Hwf4cdzYkcuSL-HDM4hxvYEhDK9K3GESJJ_FUcZ5F8Xoa2GhSgnUvdNil0KuPxHApreTevDEMlGw",
#                     "width": 1080
#                 }
#             ],
#             "place_id": "ChIJvwYXUDz_rlQRKpVyY618JMM",
#             "plus_code": {
#                 "compound_code": "JQX3+FG Boise, Idaho",
#                 "global_code": "85M5JQX3+FG"
#             },
#             "rating": 4.1,
#             "reference": "ChIJvwYXUDz_rlQRKpVyY618JMM",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 78,
#             "vicinity": "4624 W State St, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6136713,
#                     "lng": -116.2057373
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61496122989272,
#                         "lng": -116.2042701201073
#                     },
#                     "southwest": {
#                         "lat": 43.61226157010728,
#                         "lng": -116.2069697798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "b718466fdc95f8586e92b72cac5f0632bf5a24a4",
#             "name": "P.F. Chang's",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2610,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103300875995514193726/photos\">Mark Vickrey</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAV4gS37sQLhGRNlnT0CdSDyKu-sz1LYmAoZI0-fwIAD57ri0gfLy8CUS3L6CihiasiqIFVRCa42QmRRJ99YlmfUqFsJEol0Il9LezKbyPGIUldbc_hU0_fO1s-ias83n5EhCq_hen5pdULOmbwdbS6NMPGhSRUAFGH1SbUW3beZ_B7I8kZIxflQ",
#                     "width": 4640
#                 }
#             ],
#             "place_id": "ChIJEVx3TeX4rlQR4QkPYThohEg",
#             "plus_code": {
#                 "compound_code": "JQ7V+FP Boise, Idaho",
#                 "global_code": "85M5JQ7V+FP"
#             },
#             "price_level": 2,
#             "rating": 4.1,
#             "reference": "ChIJEVx3TeX4rlQR4QkPYThohEg",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 709,
#             "vicinity": "391 S 8th St, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6201152,
#                     "lng": -116.312547
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.62139177989273,
#                         "lng": -116.3111985701073
#                     },
#                     "southwest": {
#                         "lat": 43.61869212010728,
#                         "lng": -116.3138982298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "4929e977dc1f7858efe1b37024d1fa6db3684772",
#             "name": "China Grand Buffet",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101065803211505232699/photos\">Pone Dythavon</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAo5ENNgHsnU-L0F4uVvai86jTSfrDxe5ETfjfJJF3emLUB-B-Z7HjnvUudIUeoqYgIS-sbRSBNQOAOzRt9dOqyKpoyqrocUq5EpzHbm3erR7f-hJQk69nMOp1t3-X3dj9EhCZvghD1kPWtMHaLbbeoRMgGhT0KrTU9yrl2bkvBaFGtgezZ2yyEA",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJTSFfGNRVrlQRuTYkj0zGqMM",
#             "plus_code": {
#                 "compound_code": "JMCP+2X Boise, Idaho",
#                 "global_code": "85M5JMCP+2X"
#             },
#             "price_level": 1,
#             "rating": 4.1,
#             "reference": "ChIJTSFfGNRVrlQRuTYkj0zGqMM",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 1427,
#             "vicinity": "10498 W Fairview Ave, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.577295,
#                     "lng": -116.195009
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.57901292989273,
#                         "lng": -116.1936632701073
#                     },
#                     "southwest": {
#                         "lat": 43.57631327010728,
#                         "lng": -116.1963629298928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "f545045ba2cd56701c0a4aac1994c9814ae16ba4",
#             "name": "Season Wok",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2952,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104156735198363326200/photos\">David Ku</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAgWsLatTFb-r9Dqx76a7MN0Ocv5BKiDgeKA4lSa7VMyqEFExcDiREIMyghuUmwQjAyT2YYLvPbd7YnA64yTsZb0bZUhmTF67hoUCpO0vaLRGExm8TKYQBWbQIg5uIa1F6EhAoFK_-e-R182jDQ4Hg_cz8GhQ-Rvz3Q1WXZwslUKb4tuHzk4f4sQ",
#                     "width": 5248
#                 }
#             ],
#             "place_id": "ChIJ_9TdpxD4rlQRdg8ROoJbNSw",
#             "plus_code": {
#                 "compound_code": "HRG3+WX Boise, Idaho",
#                 "global_code": "85M5HRG3+WX"
#             },
#             "rating": 3.5,
#             "reference": "ChIJ_9TdpxD4rlQRdg8ROoJbNSw",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 72,
#             "vicinity": "2775 Broadway Ave, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6028923,
#                     "lng": -116.2443818
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.60420812989273,
#                         "lng": -116.2430330701073
#                     },
#                     "southwest": {
#                         "lat": 43.60150847010728,
#                         "lng": -116.2457327298928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "81e7b34efcf3b72a23a6b3223f413b90aa792d04",
#             "name": "Mandarin Palace",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112784219864839598751/photos\">laurel clark</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAUWv6xI3pmMU7IJ5VWXTQ8sCDY2ccLmaBoUFunedCzmtHe4jPlBgdGupqdFwIQ0JXDFBqVjExiZWvwOMgzjAOn55kPWlKZAAbFMvx0x4wtAxh2XN6lOckHiIx84e4nsoXEhBYcTKa1f_-t81jD19Ng4YeGhSa56rz1gdvXHJJubs8sMoSZTN3-Q",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJecwebShWrlQRo_MtO2S0rdA",
#             "plus_code": {
#                 "compound_code": "JQ34+56 Boise, Idaho",
#                 "global_code": "85M5JQ34+56"
#             },
#             "rating": 3.6,
#             "reference": "ChIJecwebShWrlQRo_MtO2S0rdA",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 116,
#             "vicinity": "5020 Franklin Rd, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6215454,
#                     "lng": -116.2180356
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.62301827989272,
#                         "lng": -116.2166851201073
#                     },
#                     "southwest": {
#                         "lat": 43.62031862010728,
#                         "lng": -116.2193847798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "af8363c6aa7b756c9c0ebc6251030024a8067dd5",
#             "name": "Sushi Joy Asian Cuisine",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3984,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108021092918480242470/photos\">Clarence Mak</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA5s_ygjO_VIPzBtOLrJJ4mkiwMwZzxbdgaf-8NxVFsfpn_kDdLVyiaWXxY-OtHQRANqynVWSIKKi37S5SNQwHdCxf5R8umSGZlDEo4VOMinowUOZk8QzIbLTH3e7vr-HSEhDAjG97KUgLZ4xivxiKpx8qGhQUWH8-BHl41ZCe9xZvCpGJkEnxyA",
#                     "width": 2988
#                 }
#             ],
#             "place_id": "ChIJCavi88L4rlQR8mDWej59VVc",
#             "plus_code": {
#                 "compound_code": "JQCJ+JQ Boise, Idaho",
#                 "global_code": "85M5JQCJ+JQ"
#             },
#             "price_level": 2,
#             "rating": 4.6,
#             "reference": "ChIJCavi88L4rlQR8mDWej59VVc",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 277,
#             "vicinity": "2275 W Main St, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.618054,
#                     "lng": -116.282076
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61940457989272,
#                         "lng": -116.2805948201073
#                     },
#                     "southwest": {
#                         "lat": 43.61670492010728,
#                         "lng": -116.2832944798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "f81ca5c2cbaac12e40248363e8e791490f61b119",
#             "name": "City Buffet",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115693378372527896308/photos\">Holger Haberfellner</a>"
#                     ],
#                     "photo_reference": "CmRaAAAADeKlBFE-6N3o1f2AK21Zn8G3y1ZUGqkXNwoEvRvXs2Q2e3RtXwu9Ax_jIJbAdsc-4QdyvZVnPPw3jT0mlCSbTlTmz-QX7Qs4bapNt4G62BuBtjoHimX8hvSQynoTDvK5EhB61IprH1IdOyuuktFz0NZYGhR5s09tMV8ekY7FOPABVkptW4qkvQ",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJDU3kvQtWrlQRqEpYSPtJ_5I",
#             "plus_code": {
#                 "compound_code": "JP99+65 Boise, Idaho",
#                 "global_code": "85M5JP99+65"
#             },
#             "price_level": 2,
#             "rating": 4,
#             "reference": "ChIJDU3kvQtWrlQRqEpYSPtJ_5I",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 433,
#             "vicinity": "8049 W Fairview Ave, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.590018,
#                     "lng": -116.2418638
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59136677989272,
#                         "lng": -116.2405863201073
#                     },
#                     "southwest": {
#                         "lat": 43.58866712010728,
#                         "lng": -116.2432859798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "2a3be484e3d636b3b1bb36a2cdb40d25e7768fe5",
#             "name": "Quik-Wok Restaurant",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104596854037149095654/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAoFqloHGtwcoHB42WUu8FZr_u-Vr8W6bN5JA05ssNsyAau5pYD35mWxweBNu7I2bD8JtgOqyHKjYgfPEreTYWfvb7a3hXg3p7pw8NRRyTD1iBWAK2_147Qma_oNQQovY-EhCvzQFIt8K2KscN_keLNySzGhSBdVL_clG_2VDiG34gMO4ni-BZeg",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJbRshL9JXrlQRDa61aB-RK2E",
#             "plus_code": {
#                 "compound_code": "HQR5+27 Boise, Idaho",
#                 "global_code": "85M5HQR5+27"
#             },
#             "price_level": 1,
#             "rating": 3.2,
#             "reference": "ChIJbRshL9JXrlQRDa61aB-RK2E",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 222,
#             "vicinity": "4858 W Overland Rd, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.5915577,
#                     "lng": -116.3116912
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59287852989272,
#                         "lng": -116.3103414201073
#                     },
#                     "southwest": {
#                         "lat": 43.59017887010728,
#                         "lng": -116.3130410798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "f2b62644707695960bbe5842c39bf0941643231f",
#             "name": "Great Wall Restaurant",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115524074643486828662/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA0ls5USgYiuRrFS7fIKLVqxhodDDKpDinAFFM_kKwvl9VkC4kan1C3Wc330-iSArFLVbIsTR7rY2JoGbMU5O85Ar06Jg7gENJayUQZLs-COpSyDmWfU4U9ecFeijkDEITEhCi-j4yxMq7PpS3M_TM7FtZGhRfAchM49rfiKnnlhP3OD68CByX2w",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJle9LyO5WrlQRyBqJqPmCLQI",
#             "plus_code": {
#                 "compound_code": "HMRQ+J8 Boise, Idaho",
#                 "global_code": "85M5HMRQ+J8"
#             },
#             "price_level": 2,
#             "rating": 3.7,
#             "reference": "ChIJle9LyO5WrlQRyBqJqPmCLQI",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_delivery",
#                 "meal_takeaway",
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 318,
#             "vicinity": "10398 W Overland Rd, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.5906315,
#                     "lng": -116.2801472
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59193827989272,
#                         "lng": -116.2788408701073
#                     },
#                     "southwest": {
#                         "lat": 43.58923862010727,
#                         "lng": -116.2815405298928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "ae08003ee569010604f4fa91f90e3d341be10ece",
#             "name": "Panda Express",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1920,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100999295664471930184/photos\">Flo Turner</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAriLHFrBdrVjUP5VnHXO0hTNsBiQqU-NwZqdCrl5v5R1UEHLx6X4P4yLkfgER__PCB4CE_kaboR7Nv9jOc5lZp77L2Bpd-MelG0Xro247vR9KyFbyVmCWvbWhztMuEWcwEhA6tJ-Vs5Fk7oSCHWlFeCu8GhTFp9OQQ5LySOSMtEZZirAVPAw06A",
#                     "width": 1080
#                 }
#             ],
#             "place_id": "ChIJb15nIlJWrlQRcvGGNq_0WC8",
#             "plus_code": {
#                 "compound_code": "HPR9+7W Boise, Idaho",
#                 "global_code": "85M5HPR9+7W"
#             },
#             "price_level": 1,
#             "rating": 4.1,
#             "reference": "ChIJb15nIlJWrlQRcvGGNq_0WC8",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_takeaway",
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 490,
#             "vicinity": "7804 W Overland Rd, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6149188,
#                     "lng": -116.2839412
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61633502989272,
#                         "lng": -116.2825102701073
#                     },
#                     "southwest": {
#                         "lat": 43.61363537010728,
#                         "lng": -116.2852099298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "94659697197e48daedd43bbf53d68e40e1baf476",
#             "name": "Panda Express",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118350779690464862712/photos\">Roxana Curtis</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAYhzbFaWBf87Xea2WThct_oLTB-Q3algQVbdeL2k7uE3KwUKGZ-bNM4Iqkan4xynRXI6DbMCXa5cYTcZPg9decu4IYR7VNcBuuk66r37LYOYEYhtHZSFX_aIkU7SdenO5EhCGxUoYAvqEPiJBazguFegFGhSDbJpohrhBIBCE0xAQVNS4mCduXA",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJbdZEMQ1WrlQRcVfVf-Hl8g8",
#             "plus_code": {
#                 "compound_code": "JP78+XC Boise, Idaho",
#                 "global_code": "85M5JP78+XC"
#             },
#             "price_level": 1,
#             "rating": 4,
#             "reference": "ChIJbdZEMQ1WrlQRcVfVf-Hl8g8",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_takeaway",
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 183,
#             "vicinity": "1124 N Milwaukee St, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.58963800000001,
#                     "lng": -116.216586
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59098947989272,
#                         "lng": -116.2151422201073
#                     },
#                     "southwest": {
#                         "lat": 43.58828982010728,
#                         "lng": -116.2178418798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "fb20fca1a524f40bfea6af8ba52d1bd870bb8e7a",
#             "name": "Panda Garden",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1836,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106174110811765380336/photos\">Jacob Keene</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAIFZFW263HozDcxWpCotA85H8sYI59wbhWVRvCF7inz8kS8-_YPbM9HmL6Gfs1ybz-0XbnW2GfEk3PkIcqC9bplRvfPLCQgaPClHzX18OJiD4Sy_qxYWCIHDsfLbqcBh_EhB4T5rAxsv5GbtSRHGHLNmBGhS7yoRXhsQwhXfXZ5wWbt-wFibL3A",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJ2VoTQ3D4rlQR3UKIMJlQFeI",
#             "plus_code": {
#                 "compound_code": "HQQM+V9 Boise, Idaho",
#                 "global_code": "85M5HQQM+V9"
#             },
#             "price_level": 2,
#             "rating": 3.9,
#             "reference": "ChIJ2VoTQ3D4rlQR3UKIMJlQFeI",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 216,
#             "vicinity": "2801 W Overland Rd, Boise"
#         }
#     ],
#     "status": "OK"
# }

# %%
# Print the name and address of the first restaurant that appears
print(places_data["results"][0]["name"])
print(places_data["results"][0]["vicinity"])
# Out:
# Yen Ching Restaurant
# 305 N 9th St, Boise

# %% [markdown]
# # Google Drills
# 1. What are the geocoordinates (latitude/longitude) of Seattle, Washington?
# 2. What are the geocoordinates (latitude/longitude) of The White House?
# 3. Find the name and address of a bike store in Seattle, Washington.
#    Hint: See https://developers.google.com/places/web-service/supported_types
# 4. Find a balloon store near the White House.
# 5. Find the nearest dentist to your house.
#    Hint: Use Google Maps to find your latitude and Google Places to find the
#    dentist. You will also need the rankby property.
# 6. Bonus: Find the names and addresses of the top five restaurants in your home city.
#    Hint: Read about "Text Search Results"
#    (https://developers.google.com/places/web-service/search#TextSearchRequests)

# %% [markdown]
# ## 1. Geocoordinates of Seattle and Washington

# %%
#Geocoordinates (latitude/longitude) of Seattle, Washington
target_place = "Seattle, Washington"
target_place_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(target_place, gkey)

# Run a request to endpoint and convert result to json
place_data = requests.get(target_place_url).json()

# Print the json
print(json.dumps(place_data, indent=4, sort_keys=True))
# Out:
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Seattle",
#                     "short_name": "Seattle",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "King County",
#                     "short_name": "King County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Washington",
#                     "short_name": "WA",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Seattle, WA, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 47.734145,
#                         "lng": -122.2244331
#                     },
#                     "southwest": {
#                         "lat": 47.4919119,
#                         "lng": -122.4596959
#                     }
#                 },
#                 "location": {
#                     "lat": 47.6062095,
#                     "lng": -122.3320708
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.734145,
#                         "lng": -122.2244331
#                     },
#                     "southwest": {
#                         "lat": 47.4919119,
#                         "lng": -122.4596959
#                     }
#                 }
#             },
#             "place_id": "ChIJVTPokywQkFQRmtVEaUZlJRA",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }

# %%
#Extract lat/lng
lat_place = place_data["results"][0]["geometry"]["location"]["lat"]
lng_place = place_data["results"][0]["geometry"]["location"]["lat"]

# Print results
print(f"{target_place}: {lat}, {lng}")
# Out:
# Seattle, Washington: 43.6150186, -116.2023137

# %% [markdown]
# ## 2. Geocoordinates of the White House

# %%
#Geocoordinates (latitude/longitude) of Seattle, Washington
target_place = "The White House"
target_place_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(target_place, gkey)

# Run a request to endpoint and convert result to json
place_data = requests.get(target_place_url).json()

#Extract lat/lng
lat_place = place_data["results"][0]["geometry"]["location"]["lat"]
lng_place = place_data["results"][0]["geometry"]["location"]["lat"]

# Print results
print(f"{target_place}: {lat}, {lng}")
# Out:
# The White House: 43.6150186, -116.2023137

# %% [markdown]
# ## 3. Name and address of a bike store in Seattle, WA
